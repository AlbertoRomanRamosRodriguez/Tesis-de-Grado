# %% [markdown]
# # MobileNet Healthy-Ill Classification of Diabetic Retinopathy in PyTorch

# %%
from __future__ import print_function, division

from torchvision import datasets, models, transforms
from sklearn.metrics import confusion_matrix
import torch.backends.cudnn as cudnn
from torch.optim import lr_scheduler

import matplotlib.pyplot as plt
import torch.optim as optim
import torch.nn as nn
import seaborn as sn
import pandas as pd
import numpy as np
import torchvision
import torch
import time
import copy
import os

cudnn.benchmark = True
plt.ion()   # interactive mode

# %%
import datetime

TIME_STAMP = datetime.datetime.today().strftime('%d_%h_%y_%H_%M')

FILENAME = f"MobileNetV3_H_I_{TIME_STAMP}"
print(FILENAME)
# Out:
# MobileNetV3_H_I_20_Feb_23_22_55

# %% [markdown]
# ## Load Data
#
# We will use torchvision and torch.utils.data packages for loading the
# data.

# %%
# Data augmentation and normalization for training
# Just normalization for validation
data_transforms = {
    'Train': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'Val': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'Test': transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

DATA_DIR = 'DB'
ds_splits = ['Train', 'Val', 'Test']
image_datasets = {x: datasets.ImageFolder(os.path.join(DATA_DIR, x),
                                          data_transforms[x])
                  for x in ds_splits}
dataloaders = {x: torch.utils.data.DataLoader(image_datasets[x], batch_size=32,
                                             shuffle=True, num_workers=4)
              for x in ds_splits}
dataset_sizes = {x: len(image_datasets[x]) for x in ds_splits}
class_names = image_datasets['Train'].classes

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Visualize a few images
# Let's visualize a few training images so as to understand the data
# augmentations.

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


# Get a batch of training data
inputs, classes = next(iter(dataloaders['Train']))

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])

# %% [markdown]
# ## Training the model
#
# Now, let's write a general function to train a model. Here, we will
# illustrate:
#
# -  Scheduling the learning rate
# -  Saving the best model
#
# In the following, parameter ``scheduler`` is an LR scheduler object from
# ``torch.optim.lr_scheduler``.

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=25):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print(f'Epoch {epoch+1}/{num_epochs - 1}')
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['Train', 'Val']:
            if phase == 'Train':
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(device)
                labels = labels.to(device)

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'Train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'Train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)
            if phase == 'Train':
                scheduler.step()

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}')

            # deep copy the model
            if phase == 'Val' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

        print()

    time_elapsed = time.time() - since
    print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
    print(f'Best val Acc: {best_acc:4f}')

    # load best model weights
    model.load_state_dict(best_model_wts)
    return model

# %% [markdown]
# ### Visualizing the model predictions
#
# Generic function to display predictions for a few images

# %%
def visualize_model(model, num_images=6):
    was_training = model.training
    model.eval()
    images_so_far = 0
    fig = plt.figure()

    with torch.no_grad():
        for i, (inputs, labels) in enumerate(dataloaders['Test']):
            inputs = inputs.to(device)
            labels = labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            for j in range(inputs.size()[0]):
                images_so_far += 1
                ax = plt.subplot(num_images//2, 2, images_so_far)
                ax.axis('off')
                

                ax.set_title(f'predicted: {class_names[preds[j]]}, label: {labels[j]}')
                imshow(inputs.cpu().data[j])

                if images_so_far == num_images:
                    model.train(mode=was_training)
                    return
        model.train(mode=was_training)

# %% [markdown]
# ## Finetuning the convnet
#
# Load a pretrained model and reset final fully connected layer.

# %%
model_ft = models.mobilenet_v3_small(weights=models.MobileNet_V3_Small_Weights.IMAGENET1K_V1)
num_ftrs = model_ft.classifier[-1].in_features
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).
model_ft.classifier[-1] = nn.Linear(num_ftrs, 2)

model_ft = model_ft.to(device)

criterion = nn.CrossEntropyLoss()

# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.parameters(), lr=0.001, momentum=0.9)

# Decay LR by a factor of 0.1 every 7 epochs
exp_lr_scheduler = lr_scheduler.StepLR(optimizer_ft, step_size=7, gamma=0.1)

print(model_ft.classifier)

model_ft = train_model(model_ft, criterion, optimizer_ft, exp_lr_scheduler,
                       num_epochs=50)
# Out:
# Train Loss: 0.6887 Acc: 0.5598
# Val Loss: 0.7166 Acc: 0.5329
#
# Epoch 2/49
# ----------
# Train Loss: 0.6556 Acc: 0.6118
# Val Loss: 0.7358 Acc: 0.5271
#
# Epoch 3/49
# ----------
# Train Loss: 0.6315 Acc: 0.6486
# Val Loss: 0.7058 Acc: 0.5529
#
# Epoch 4/49
# ----------
# Train Loss: 0.6070 Acc: 0.6793
# Val Loss: 0.6998 Acc: 0.5671
#
# Epoch 5/49
# ----------
# Train Loss: 0.5867 Acc: 0.6854
# Val Loss: 0.6871 Acc: 0.5900
#
# Epoch 6/49
# ----------
# Train Loss: 0.5625 Acc: 0.7252
# Val Loss: 0.6503 Acc: 0.6271
#
# Epoch 7/49
# ----------
# Train Loss: 0.5663 Acc: 0.7140
# Val Loss: 0.6420 Acc: 0.6343
#
# Epoch 8/49
# ----------
# Train Loss: 0.5420 Acc: 0.7293
# Val Loss: 0.6053 Acc: 0.6686
#
# Epoch 9/49
# ----------
# Train Loss: 0.5352 Acc: 0.7416
# Val Loss: 0.5778 Acc: 0.6929
#
# Epoch 10/49
# ----------
# Train Loss: 0.5269 Acc: 0.7497
# Val Loss: 0.5443 Acc: 0.7243
#
# Epoch 11/49
# ----------
# Train Loss: 0.5323 Acc: 0.7395
# Val Loss: 0.5280 Acc: 0.7471
#
# Epoch 12/49
# ----------
# Train Loss: 0.5344 Acc: 0.7293
# Val Loss: 0.5158 Acc: 0.7600
#
# Epoch 13/49
# ----------
# Train Loss: 0.5306 Acc: 0.7385
# Val Loss: 0.5061 Acc: 0.7729
#
# Epoch 14/49
# ----------
# Train Loss: 0.5225 Acc: 0.7579
# Val Loss: 0.4989 Acc: 0.7657
#
# Epoch 15/49
# ----------
# Train Loss: 0.5263 Acc: 0.7569
# Val Loss: 0.4963 Acc: 0.7686
#
# Epoch 16/49
# ----------
# Train Loss: 0.5266 Acc: 0.7283
# Val Loss: 0.4947 Acc: 0.7829
#
# Epoch 17/49
# ----------
# Train Loss: 0.5325 Acc: 0.7497
# Val Loss: 0.4937 Acc: 0.7829
#
# Epoch 18/49
# ----------
# Train Loss: 0.5244 Acc: 0.7528
# Val Loss: 0.4931 Acc: 0.7829
#
# Epoch 19/49
# ----------
# Train Loss: 0.5311 Acc: 0.7426
# Val Loss: 0.4927 Acc: 0.7800
#
# Epoch 20/49
# ----------
# Train Loss: 0.5185 Acc: 0.7508
# Val Loss: 0.4920 Acc: 0.7857
#
# Epoch 21/49
# ----------
# Train Loss: 0.5138 Acc: 0.7436
# Val Loss: 0.4912 Acc: 0.7871
#
# Epoch 22/49
# ----------
# Train Loss: 0.5172 Acc: 0.7681
# Val Loss: 0.4912 Acc: 0.7857
#
# Epoch 23/49
# ----------
# Train Loss: 0.5288 Acc: 0.7354
# Val Loss: 0.4912 Acc: 0.7843
#
# Epoch 24/49
# ----------
# Train Loss: 0.5306 Acc: 0.7518
# Val Loss: 0.4912 Acc: 0.7843
#
# Epoch 25/49
# ----------
# Train Loss: 0.5256 Acc: 0.7446
# Val Loss: 0.4911 Acc: 0.7843
#
# Epoch 26/49
# ----------
# Train Loss: 0.5209 Acc: 0.7589
# Val Loss: 0.4911 Acc: 0.7857
#
# Epoch 27/49
# ----------
# Train Loss: 0.5264 Acc: 0.7508
# Val Loss: 0.4910 Acc: 0.7871
#
# Epoch 28/49
# ----------
# Train Loss: 0.5176 Acc: 0.7518
# Val Loss: 0.4910 Acc: 0.7843
#
# Epoch 29/49
# ----------
# Train Loss: 0.5191 Acc: 0.7477
# Val Loss: 0.4910 Acc: 0.7857
#
# Epoch 30/49
# ----------
# Train Loss: 0.5190 Acc: 0.7446
# Val Loss: 0.4910 Acc: 0.7814
#
# Epoch 31/49
# ----------
# Train Loss: 0.5230 Acc: 0.7497
# Val Loss: 0.4910 Acc: 0.7829
#
# Epoch 32/49
# ----------
# Train Loss: 0.5141 Acc: 0.7712
# Val Loss: 0.4911 Acc: 0.7829
#
# Epoch 33/49
# ----------
# Train Loss: 0.5067 Acc: 0.7610
# Val Loss: 0.4910 Acc: 0.7857
#
# Epoch 34/49
# ----------
# Train Loss: 0.5234 Acc: 0.7569
# Val Loss: 0.4910 Acc: 0.7857
#
# Epoch 35/49
# ----------
# Train Loss: 0.5164 Acc: 0.7579
# Val Loss: 0.4910 Acc: 0.7843
#
# Epoch 36/49
# ----------
# Train Loss: 0.5230 Acc: 0.7497
# Val Loss: 0.4911 Acc: 0.7829
#
# Epoch 37/49
# ----------
# Train Loss: 0.5200 Acc: 0.7518
# Val Loss: 0.4912 Acc: 0.7829
#
# Epoch 38/49
# ----------
# Train Loss: 0.5177 Acc: 0.7651
# Val Loss: 0.4911 Acc: 0.7857
#
# Epoch 39/49
# ----------
# Train Loss: 0.5142 Acc: 0.7661
# Val Loss: 0.4910 Acc: 0.7843
#
# Epoch 40/49
# ----------
# Train Loss: 0.5208 Acc: 0.7487
# Val Loss: 0.4911 Acc: 0.7843
#
# Epoch 41/49
# ----------
# Train Loss: 0.5170 Acc: 0.7528
# Val Loss: 0.4911 Acc: 0.7843
#
# Epoch 42/49
# ----------
# Train Loss: 0.5199 Acc: 0.7436
# Val Loss: 0.4912 Acc: 0.7843
#
# Epoch 43/49
# ----------
# Train Loss: 0.5161 Acc: 0.7692
# Val Loss: 0.4911 Acc: 0.7829
#
# Epoch 44/49
# ----------
# Train Loss: 0.5228 Acc: 0.7487
# Val Loss: 0.4911 Acc: 0.7829
#
# Epoch 45/49
# ----------
# Train Loss: 0.5205 Acc: 0.7477
# Val Loss: 0.4912 Acc: 0.7843
#
# Epoch 46/49
# ----------
# Train Loss: 0.5149 Acc: 0.7446
# Val Loss: 0.4912 Acc: 0.7857
#
# Epoch 47/49
# ----------
# Train Loss: 0.5203 Acc: 0.7487
# Val Loss: 0.4913 Acc: 0.7843
#
# Epoch 48/49
# ----------
# Train Loss: 0.5218 Acc: 0.7528
# Val Loss: 0.4910 Acc: 0.7843
#
# Epoch 49/49
# ----------
# Train Loss: 0.5208 Acc: 0.7477
# Val Loss: 0.4910 Acc: 0.7843
#
# Epoch 50/49
# ----------
# Train Loss: 0.5236 Acc: 0.7375
# Val Loss: 0.4910 Acc: 0.7871
#
# Training complete in 15m 16s
# Best val Acc: 0.787143

# %% [markdown]
# ### Train and evaluate

# %%
MODEL_PATH = os.path.sep.join(['models',f'{FILENAME}.pt'])
torch.save(model_ft.state_dict(),MODEL_PATH)

# %%
model_ft.load_state_dict(torch.load(MODEL_PATH)) #change to evaluate another PYTORCH model
visualize_model(model_ft)

# %%
y_pred = []
y_true = []

print("[INFO] Iterating predictions")
# iterate over test data
for inputs, labels in dataloaders['Test']:
        output = model_ft(inputs) # Feed Network

        output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
        y_pred.extend(output) # Save Prediction
        
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) # Save Truth
# Out:
# [INFO] Iterating predictions

# %%
print("[INFO] Building Matrix")
# constant for classes
classes = ('No DR', 'DR')

def get_matrix(cfm: np.ndarray, pct:True):
        if pct:
                return cfm / np.sum(cfm, axis=1)
        else:
                return cfm

OUTPATH = os.path.sep.join(['output',f'{FILENAME}'])
if not os.path.exists(OUTPATH):
        os.mkdir(OUTPATH)

# Build confusion matrix
cf_matrix = confusion_matrix(y_true, y_pred)
for pct in (False, True):
        df_cm = pd.DataFrame(get_matrix(cfm=cf_matrix,pct=pct), index = [i for i in classes],
                        columns = [i for i in classes])
        plt.figure(figsize = (12,7))
        sn.heatmap(df_cm, annot=True)
        cm_path = os.path.sep.join([OUTPATH, f'confusion_matrix_pct_{pct}.png'])
        plt.savefig(cm_path)
# Out:
# [INFO] Building Matrix
